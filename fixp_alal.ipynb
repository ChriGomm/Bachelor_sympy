# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
y = np.linspace((1-np.sqrt(5))/2,(1+np.sqrt(5))/2,100)
# y0 = (1-np.sqrt(5))/2
z = np.linspace(0.45,1.5)
# y_asym = np.concatenate((np.linspace((1-np.sqrt(5))/2,0.5),np.linspace(1.5,(1+np.sqrt(5))/2)))
y_asym = np.linspace((1-np.sqrt(5))/2,0.55)
x = np.sqrt(1+y-y**2+1/10**14)
stab = y-y**3
# zero_y = (1+2*y_asym**2+y_asym**3)/(y_asym-1)
zero_y = -(1-2*y**2+y**3)-x**2*(y-1)
plt.figure()
plt.plot(y,x)
# plt.plot(y,stab)
# plt.plot(y,zero_y)

# plt.plot(y,1+y-y**2)
plt.show()
# -(1+2*y0**2+y0**3)+np.sqrt(1+y0-y0**2)**2*(y0-1)
a = -z**2+z+z**3
plt.figure()
plt.plot(z,-a/(z-2))
plt.plot(z,-1/2/z-z**2+1+z)
plt.hlines(y=0,xmin=z[0],xmax=z[-1],colors='black')
plt.show()

# %%
y = np.linspace(-0.5,0.2)
B=0
A= 1/6
b = 2+A+3*y**2-4*y+1
s = b**2
c = -4*(1-3*y+2*y**2)-4*(2*(A+3*y**2-4*y+1))
y0 = -B-y**3-(1+A)*y+2*y**2
l1 = -A - y**2 +y
plt.figure()
# plt.plot(y,c)
plt.plot(y,s)
# plt.plot(y,c)
plt.hlines(y=0,xmin=y[0],xmax=y[-1],colors='black')
plt.show()
plt.figure()
# plt.plot(y,b)
plt.plot(y,c)
plt.plot(y,y0)
plt.hlines(y=0,xmin=y[0],xmax=y[-1],colors='black')
plt.plot(y,l1)
plt.show()
for A in (1/6+0.05,1/6+0.1):
    A=0
    b = 2+A+3*y**2-4*y+1
    s = b**2
    c = -4*(1-3*y+2*y**2)-4*(2*(A+3*y**2-4*y+1))
    y0 = -B-y**3-(1+A)*y+2*y**2
    l1 = -A - y**2 +y
    fig, ax = plt.subplots(3,1,sharex=True)
    fig.subplots_adjust(hspace=0)
    ax[0].plot(y,c)
    ax[0].hlines(y=0,xmin=y[0],xmax=y[-1],colors='black')
    ax[0].set_ylabel('stab')
    ax[1].plot(y,y0)
    ax[1].hlines(y=0,xmin=y[0],xmax=y[-1],colors='black')
    ax[1].set_ylabel('intersect')
    ax[2].set_ylabel(r'$\lambda_1$')
    ax[2].plot(y,l1)
    ax[2].hlines(y=0,xmin=y[0],xmax=y[-1],colors='black')
    plt.show()
    break

# %%
A = np.linspace(-0.5+1/10**4,1/3-1/10**4,500)
B = 2*A/(-1+np.sqrt(1+2*A))
y = (3+np.sqrt(3-3*A))/3
# F = 2*y**3-2*y**2
F = 2*y**3-3*y**2+4*y
fig, ax = plt.subplots(1,1,layout='constrained')
ax.plot(A,F)
ax.plot(A,B)
import types
import matplotlib.text as text
SHIFT = 10. # Data coordinates
# ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
# ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.25))
# ax.xaxis.set_major_locator(ticker.MultipleLocator(0.25))
# ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.05))
# ax.tick_params(axis='x',direction='in',which='both',bottom=True,top=True,labelbottom=True)
# # for label in ax.yaxis.get_majorticklabels():
# #     label.customShiftValue = SHIFT
# #     label.set_y = types.MethodType( lambda self, x: text.Text.set_y(self, x-self.customShiftValue ),  label, text.Text )
# ax.tick_params(axis='y',direction='in',which='both',left=True,right=True,labelleft=True)
# plt.setp(ax.xaxis.get_majorticklabels())
# plt.setp(ax.yaxis.get_majorticklabels(),va='bottom')
# # ax.set_xlim(-0.5,0)
# ax.set_ylim(0,2)

y0 =(2+np.sqrt(1+3/2))/3
2*(y0**3-y0**2)
# print(ax.get_yticklabels())
# labels = ax.yaxis.get_majorticklabels()
# print(labels)
# for label in labels:
#     label.set(y=label.get_position()[1]+0.1)
# print(labels)
# ax.set_yticklabels(labels)
# print(ax.get_yticklabels())

plt.show()
# plt.getp(ax.yaxis.get_majorticklabels())

# %%
x = np.linspace(-0.5,1/4)
f1= (2-np.sqrt(1-3*x))/3
f2= (1-np.sqrt(1-4*x))/2
plt.figure()
plt.plot(x,f1)
plt.plot(x,f2)
plt.show()

# %%
from scipy.optimize import root_scalar
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
A = np.linspace(-5,0,30)
def func_B(a):
    if a<0:
        return -a #2*a/(-1-np.sqrt(1+8*a))
    else:
        return 0
root = []
conv = []
def minF(a):
    return (2-np.sqrt(1-3*a))/3
def maxF(a):
    return (2+np.sqrt(1-3*a))/3
# for a in A:
#     def func_y(y):
#         return -func_B(a)-(a+1)*y-y**3+2*y**2
#     r=root_scalar(func_y,bracket=[minF(a)-1/10**3,maxF(a)+1/10**3],x0=(maxF(a)+minF(a))/2)
#     conv.append(r.converged)
#     root.append(r.root)
# print(conv)

# root=np.array(root)
# print(root)
def root_lam1(a):
    return (1-np.sqrt(1-4*a))/2
def root_lam2(a):
    return (1+np.sqrt(1-4*a))/2
cm = 1/2.54  
width = 8*cm 
name_of_plot = "sign_of_ev1.pdf"
major_xtick_step = 1
minor_xtick_step = 0.2
major_ytick_step = 1
minor_ytick_step = 0.1
STRIP_OF_ZEROS_X = False
STRIP_OF_ZEROS_Y = False
                                                                              
fig, ax = plt.subplots(1,1,layout='constrained',figsize=(width,4.8/6.4*width),dpi=400)

# ax.scatter(A,root,color='0')
ax.plot(A,root_lam2(A),color='#DC143C',alpha=0.7)
ax.plot(A,maxF(A),color='#653700',alpha=0.7)
ax.plot(A,root_lam1(A),color='#FFD700',alpha=0.7)


ax.fill_between(A,-2.5,root_lam1(A),color='0.1')
ax.fill_between(A,1,maxF(A),color='0.3')
ax.fill_between(A,maxF(A),3.5,color='0.7')
# axlimits have to be adapted
ax.set_xlim(A[0],A[-1])
ax.set_ylim(-2.5,3.5)

# legend has to be adapted
plt.legend([r'$r_{\lambda_1}^{max}$',r'$\tilde{y}_{max}$',r'$r_{\lambda_1}^{min}$'],loc='center left',bbox_to_anchor=(0.01,0.38))
# plt.legend([r'$r$',r'$r$',r'$y_{max}$'],loc='center left',bbox_to_anchor=(0.2,0.5))

plt.rcParams["lines.markersize"]=0.7
plt.rcParams["axes.unicode_minus"]=True
plt.rcParams["font.size"]=10
plt.rcParams["text.usetex"]=True
plt.rcParams["font.serif"]="Computer Modern Serif"
# def strip0(x,pos):
#     if x<0: 
#         return u'\u2212'+ str(x).rstrip(".0").lstrip("-")
#     else:
#         if str(x).rstrip(".0"):
#             return str(x).rstrip(".0")
#     return "0"
def strip0(x,pos):
    if x==0:
        return "0"
    if x<-3/16/2: 
        return u'\u2212'+ '1/8' #str(x).rstrip(".0").lstrip("-")
    else:
        return u'\u2212'+ '1/16'
ax.yaxis.set_major_locator(ticker.MultipleLocator(major_ytick_step))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(minor_ytick_step))
ax.xaxis.set_major_locator(ticker.MultipleLocator(major_xtick_step))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(minor_xtick_step))
if STRIP_OF_ZEROS_X:
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(strip0))
# if STRIP_OF_ZEROS_Y:
#     ax.yaxis.set_major_formatter(ticker.FuncFormatter(strip0))  
ax.tick_params(axis='x',direction='in',which='both',bottom=True,top=True,labelbottom=True)
ax.tick_params(axis='both',which='major',length=4.5)
ax.tick_params(axis='y',direction='in',which='both',left=True,right=True,labelleft=True)
ax.set_xlabel(r'$\Gamma \tilde{A}$')
ax.set_ylabel(r'$\tilde{y}$',rotation=0)
plt.setp(ax.yaxis.get_majorticklabels(),va='bottom')
ax.text(-2.6,2.7,r'largest $\tilde{y}$-value')
ax.text(-4.5,1.3,r'middle',color='1')
ax.text(-2.5,-1.9,r'smallest $\tilde{y}$-value',color='1')
# save figure
# plt.savefig('/home/christian/Documents/Bachelor/protocol/pictures/'+name_of_plot,bbox_inches='tight')

plt.show()

# %%
k = np.linspace(0,20)
ytilde = 1/(3+8*k)*(2+6*k-np.sqrt(5/2+8*k+4*k**2))
plt.figure()
plt.plot(k,ytilde)
plt.show()

# %%
from scipy.optimize import root_scalar
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker




    # if a<0:
    #     return -a #2*a/(-1-np.sqrt(1+8*a))
    # else:
    #     return 0
root = []
conv = []
def minF(a,kw):
    return (2-np.sqrt(1-3*kw**2*a))/3
def maxF(a,kw):
    return (2+np.sqrt(1-3*kw**2*a))/3


# root=np.array(root)
# print(root)
def root_lam1(a):
    return (1-np.sqrt(1-4*a))/2
def root_lam2(a):
    return (1+np.sqrt(1-4*a))/2
cm = 1/2.54  
width = 12*cm 
name_of_plot = "sign_of_ev1.pdf"
major_xtick_step = 5
minor_xtick_step = 1
major_ytick_step = 5
minor_ytick_step = 1
STRIP_OF_ZEROS_X = True
STRIP_OF_ZEROS_Y = True
                                                                              
fig, ax = plt.subplots(1,1,figsize=(width,4.8/6.4*width),dpi=400)

# ax.scatter(A,root,color='0')




# axlimits have to be adapted
# ax.set_xlim(A[0],A[-1])
# ax.set_ylim(-2.5,3.5)

# legend has to be adapted
# plt.legend([r'$r_{\lambda_1}^{max}$',r'$\tilde{y}_{max}$',r'$r_{\lambda_1}^{min}$'],loc='center left',bbox_to_anchor=(0.01,0.38))
# plt.legend([r'$r$',r'$r$',r'$y_{max}$'],loc='center left',bbox_to_anchor=(0.2,0.5))

plt.rcParams["lines.markersize"]=0.7
plt.rcParams["axes.unicode_minus"]=True
plt.rcParams["font.size"]=10
plt.rcParams["text.usetex"]=True
plt.rcParams["font.serif"]="Computer Modern Serif"
# def strip0(x,pos):
#     if x<0: 
#         return u'\u2212'+ str(x).rstrip(".0").lstrip("-")
#     else:
#         if str(x).rstrip(".0"):
#             return str(x).rstrip(".0")
#     return "0"
def formatx(x,pos):
    try:
        return "{:.2f}".format(kw[int(x)])
    except:
        return ""
def formaty(x,pos):
    try:
        return "{:.2f}".format(A[int(x)])
    except:
        return ""
ax.yaxis.set_major_locator(ticker.MultipleLocator(major_ytick_step))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(minor_ytick_step))
ax.xaxis.set_major_locator(ticker.MultipleLocator(major_xtick_step))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(minor_xtick_step))
if STRIP_OF_ZEROS_X:
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatx))
if STRIP_OF_ZEROS_Y:
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(formaty))  
ax.tick_params(axis='x',direction='in',which='both',bottom=True,top=True,labelbottom=True)
ax.tick_params(axis='both',which='major',length=4.5)
ax.tick_params(axis='y',direction='in',which='both',left=True,right=True,labelleft=True)
# ax.set_xlabel(r'$\Gamma \tilde{A}$')
# ax.set_ylabel(r'$\tilde{y}$',rotation=0)
plt.setp(ax.yaxis.get_majorticklabels(),va='center')
# ax.text(-2.6,2.7,r'largest $\tilde{y}$-value')
# ax.text(-4.5,1.3,r'middle',color='1')
# ax.text(-2.5,-1.9,r'smallest $\tilde{y}$-value',color='1')
# save figure
# plt.savefig('/home/christian/Documents/Bachelor/protocol/pictures/'+name_of_plot,bbox_inches='tight')

kw = np.stack((np.linspace(0.005,0.27,30),np.linspace(6,40,30)),axis=1)
Gam = 1
sgam = 0.2*Gam
# A = np.linspace(-1/(8*(1+sgam/Gam))+1/10**6,0-1/10**6,30)
A = np.linspace(-0.01,0-1/10**6,30)
def kappa_np(A,Gam,sgam,mp):
    res =Gam/2/A*(-1/np.sqrt(2)+mp*np.sqrt(1/2+4*A+4*A*sgam/Gam))
    if res>=0:
        return res
    else:
        return Gam/2/A*(-1/np.sqrt(2)+np.sqrt(1/2+4*A+4*A*sgam/Gam))
def func_B(kw,A,Gam,sgam,mp):
    return kw**2*Gam/np.sqrt(2)/kappa_np(A,Gam,sgam,mp)

# plt.figure()
# plt.plot(kw[-1,0]**2*A,func_B(kw[-1,0],A,Gam,sgam,-1))
# plt.plot(kw[-1,0]**2*A,kw[-1,0]**2*A)
# plt.show()

def Func(y,A,kw,Gam,sgam,mp):
    return -func_B(kw,A,Gam,sgam,mp)-(kw**2*A+1)*y-y**3+2*y**2

def lam1(y,A,kw,Gam,sgam,mp):
    p = 2*Gam**2*kw**2+A*kw**2+3*y**2-4*y+1
    q = 2*Gam**2*kw**2*(A*kw**2+3*y**2-4*y+1)+2*Gam**2*kappa_np(A,Gam,sgam,mp)**2*(2*y-kw)*(y-kw)
    return (-p+np.sqrt(p**2-4*q))/2, p,p**2-4*q

def lam2(y,A,kw,Gam,sgam,mp):
    p = 2*Gam**2*kw**2+A*kw**2+3*y**2-4*y+1
    q = 2*Gam**2*kw**2*(A*kw**2+3*y**2-4*y+1)+2*Gam**2*kappa_np(A,Gam,sgam,mp)**2*(2*y-kw)*(y-kw)
    return (-p-np.sqrt(p**2-4*q))/2, p,p**2-4*q

root = np.zeros((A.shape[0],kw.shape[0]))
conv= np.zeros((A.shape[0],kw.shape[0]))
check = np.zeros((A.shape[0],kw.shape[0]))
lamda= np.zeros((A.shape[0],kw.shape[0],kw.shape[1]))
damp = np.zeros((A.shape[0],kw.shape[0],kw.shape[1]))

mp =-1
for k in range(1,kw.shape[1]):
    for i in range(np.shape(A)[0]):
        for j in range(np.shape(kw)[0]):
            a = A[i]
            kw_val = kw[j,k]
            print(Func(minF(a,kw_val),a,kw_val,Gam,sgam,mp),Func(maxF(a,kw_val),a,kw_val,Gam,sgam,mp))
            try:
                r=root_scalar(Func,args=(a,kw_val,Gam,sgam,mp),method='bisect',bracket=(minF(a,kw_val),maxF(a,kw_val)))
                # print(r.root)
            except:
                print(k,i,j)
                
            # bracket=[minF(a)-1/10**3,maxF(a)+1/10**3],
            # check[i,j] = func_B(kw_val,a,Gam,sgam,mp)
            conv[i,j]= r.converged
            root[i,j]= r.root
            trash,damp[i,j,k], lamda[i,j,k]= lam1(r.root,a,kw_val,Gam,sgam,mp)
# print(check)
# print(root[0,:])

# ax.plot(A,kappa_np(A,Gam,sgam,mp))

im = ax.imshow(damp[:,:,1])
# ax.set_xticks(np.arange(len(kw)),kw)
# ax.set_yticks(np.arange(len(A)),A)
cbar = ax.figure.colorbar(im,ax=ax)
fig.tight_layout()
plt.show()
# Out:
# -0.42536426938873073 0.019053310046238447
# -0.5589740361395293 0.041914675694112
# -0.7259322042522521 0.07841006763846803
# -0.9297512586318912 0.13205197078429798
# -1.1740141466097234 0.20642333246287947
# -1.4623480224504004 0.3051513069388636
# -1.7984084795750557 0.4318914876333855
# -2.1858698801428904 0.5903182367056425
# -2.6284192816944616 0.7841186116961945
# -3.129752529503736 1.0169884578790072
# -3.6935716826801386 1.2926298343635043
# -4.32358328075956 1.6147492806855812
# -5.023497151933313 1.987056625036547
# -5.797025577837204 2.4132641490522087
# -6.647882697804999 2.897085992066332
# -7.579784076971996 3.442237719214215
# -8.596446388449422 4.052436003607086
# -9.70158717619956 4.731398389207224
# -10.898924675859735 5.482843111651962
# -12.192177677756089 6.310488961267433
# -13.585065421029629 7.218055177194646
# -15.081307510980405 8.209261364733658
# -16.684623853931647 9.287827430207692
# -18.398734605451224 10.457473529184616
# -20.22736012885565 11.721920024980951
# -22.174220961701163 13.084887455152934
# -24.243037788531478 14.550096504244266
# -26.437531418565776 16.12126798147416
# -28.761422767316624 17.802122802355136
# -31.2184328413558 19.59638197345901
# -0.41465580826601417 0.01788092183439316
# -0.5427810332543085 0.03934859375009703
# -0.7027250051346191 0.07364885127787968
# -0.8978103389148183 0.12410430942561268
# -1.1314292517691915 0.19410718536758376
# -1.4070178513090958 0.28709358671514673
# -1.7280405945866457 0.4065279705204192
# -2.0979807080145223 0.5558935631960793
# -2.5203341462591866 0.7386863194085898
# -2.9986056926497167 0.958411022487029
# -3.5363063837905386 1.218578709035821
# -4.136951771393976 1.5227049307672944
# -4.80406072509921 1.8743085573206244
# -5.541154592217552 2.2769109360071225
# -6.351756597635369 2.7340352917131643
# -7.239391408299965 3.2492062913860416
# -8.207584812439706 3.82594972325413
# -9.259863480047276 4.467792257310109
# -10.399754781773236 5.178261264204543
# -11.630786650381815 5.960884676701649
# -12.956487473617194 6.819190882545621
# -14.380386010525852 7.756708640782945
# -15.90601132548869 8.776967015794503
# -17.536892735762194 9.883495324836788
# -0.45192927868198035 0.034453333149475185
# -0.4754188805292016 0.0391259874875729
# -0.4999766735700174 0.04423150410634635
# -0.5256246291211482 0.04979185432251443
# -0.5523848737341795 0.05582916468766408
# -0.5802796754180255 0.062365703210708556
# -0.14817214855854272 2.3759350042951155e-10
# -0.1481824446129514 5.381268763926528e-10
# -0.14819457362582744 1.0451284282453344e-09
# -0.14820853567217945 1.8336070439772811e-09
# -0.14822433083834688 2.989902991856752e-09
# -0.14824195922199734 4.611682591360022e-09
# -0.14826142093212552 6.807940877706642e-09
# -0.1482827160890503 9.698997160967338e-09
# -0.14830584482441247 1.3416492361528753e-08
# -0.14833080728117207 1.8103386345558192e-08
# -0.14835760361360548 2.3913954816379146e-08
# -0.14838623398730205 3.1013788426292876e-08
# -0.14841669857916087 3.957978478297264e-08
# -0.1484489975773872 4.9800150225820516e-08
# -0.14848313118148831 6.187439050009402e-08
# -0.14851909960226964 7.601331342144135e-08
# -0.14855690306183036 9.243901688549272e-08
# -0.14859654179355894 1.1138488886786035e-07
# -0.14863801604212795 1.330956029832464e-07
# -0.14868132606348966 1.5782711093592638e-07
# -0.14872647212487042 1.8584663852294625e-07
# -0.14877345450476503 2.1743268208140876e-07
# -0.14882227349293164 2.528749978303324e-07
# -0.14887292939038504 2.9247460231474065e-07
# -0.14892542250939117 3.3654376085934246e-07
# -0.14897975317346027 3.854059831276402e-07
# -0.14903592171734045 4.393960182369483e-07
# -0.14909392848701097 4.988598445443415e-07
# -0.14915377383967512 5.64154665649852e-07
# -0.1492154581437526 6.356489010705957e-07
# /tmp/ipykernel_226489/4037216535.py:119: RuntimeWarning: invalid value encountered in sqrt
#   return (-p+np.sqrt(p**2-4*q))/2, p,p**2-4*q

# %%
fig, ax = plt.subplots(1,1)

plt.rcParams["lines.markersize"]=0.7
plt.rcParams["axes.unicode_minus"]=True
plt.rcParams["font.size"]=10
plt.rcParams["text.usetex"]=True
plt.rcParams["font.serif"]="Computer Modern Serif"
# def strip0(x,pos):
#     if x<0: 
#         return u'\u2212'+ str(x).rstrip(".0").lstrip("-")
#     else:
#         if str(x).rstrip(".0"):
#             return str(x).rstrip(".0")
#     return "0"
im.set_extent((-0.5,39.5,29.5,-0.5))
trash, xw, yw, trash= im.get_extent()
numb_xticks = xw//major_xtick_step+1
numb_yticks = yw//major_ytick_step+1
def formatx0(x,pos):
    try:
            # print(x,pos)#,"{:.2f}".format(kw[int(x)]))
           
        index = int((pos-1)*kw.shape[0]//numb_xticks)
           # print(index)
           # print()
        return "{:.2f}".format(kw[index,0])
    except:
        return "{:.2f}".format(kw[-1,0])
def formatx1(x,pos):
    try:
            # print(x,pos)#,"{:.2f}".format(kw[int(x)]))

        index = int((pos-1)*kw.shape[0]//numb_xticks)
           # print(index)
           # print()
        return "{:.1f}".format(kw[index,1])
    except:
        return "{:.1f}".format(kw[-1,1])

if STRIP_OF_ZEROS_X:
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatx0))
ax.yaxis.set_major_locator(ticker.MultipleLocator(major_ytick_step))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(minor_ytick_step))
ax.xaxis.set_major_locator(ticker.MultipleLocator(major_xtick_step))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(minor_xtick_step))

if STRIP_OF_ZEROS_Y:
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(formaty))  
ax.tick_params(axis='x',direction='in',which='both',bottom=True,top=True,labelbottom=True)
ax.tick_params(axis='both',which='major',length=4.5)
ax.tick_params(axis='y',direction='in',which='both',left=True,right=True,labelleft=True)
# ax.set_xlabel(r'$\Gamma \tilde{A}$')
# ax.set_ylabel(r'$\tilde{y}$',rotation=0)
plt.setp(ax.yaxis.get_majorticklabels(),va='center')


def testB(G,kw,a,gamma):
    return 2*kw**2*a/(-1+8*(1+G/gamma)*a)
def ymax(kw,a):
    return (2+np.sqrt(1-3*kw**2*a))/3
def testFunc(G,kw,a,gamma):
    return 2*ymax(kw,a)**3-2*ymax(kw,a)**2

kw = np.stack((np.linspace(0.005,0.27,30),np.linspace(6,40,30)),axis=1)
Gam = 0.25
sgam = 0.2*Gam
A = np.linspace(-1/(8*(1+sgam/Gam))+1/10**6,0-1/10**6,30)
# A = np.linspace(-0.01,0-1/10**6,30)

solu = np.zeros((A.shape[0],kw.shape[0]))
atest = kw[3,0]*np.ones_like(A)
for i in range(A.shape[0]):
    for j in range(kw.shape[0]):
        a = A[i]
        kw_val = kw[j,1]
        solu[i,j]= Func(maxF(a,kw_val),a,kw_val,Gam,sgam,-1) #-func_B(kw_val,a,Gam,sgam,-1) +testFunc(Gam,kw_val,a,sgam)

im = plt.imshow(solu)
bar = ax.figure.colorbar(im,ax=ax)
fig.tight_layout()
plt.show()

solu[:,0], A
# Out:
# (array([-1.87497625e+00, -7.41181668e-01, -3.97798001e-01, -1.86137902e-01,
#         -4.14357219e-02,  6.14264306e-02,  1.35355738e-01,  1.88042019e-01,
#          2.24516341e-01,  2.48293051e-01,  2.61950149e-01,  2.67452852e-01,
#          2.66347065e-01,  2.59881646e-01,  2.49089258e-01,  2.34841945e-01,
#          2.17890672e-01,  1.98894388e-01,  1.78442105e-01,  1.57070285e-01,
#          1.35277129e-01,  1.13534961e-01,  9.23016842e-02,  7.20322820e-02,
#          5.31914878e-02,  3.62692097e-02,  2.18013413e-02,  1.04008994e-02,
#          2.81009927e-03,  2.37593500e-10]),
#  array([-1.04165667e-01, -1.00573782e-01, -9.69818966e-02, -9.33900115e-02,
#         -8.97981264e-02, -8.62062414e-02, -8.26143563e-02, -7.90224713e-02,
#         -7.54305862e-02, -7.18387011e-02, -6.82468161e-02, -6.46549310e-02,
#         -6.10630460e-02, -5.74711609e-02, -5.38792759e-02, -5.02873908e-02,
#         -4.66955057e-02, -4.31036207e-02, -3.95117356e-02, -3.59198506e-02,
#         -3.23279655e-02, -2.87360805e-02, -2.51441954e-02, -2.15523103e-02,
#         -1.79604253e-02, -1.43685402e-02, -1.07766552e-02, -7.18477011e-03,
#         -3.59288506e-03, -1.00000000e-06]))

# %%
kw = np.linspace(0,10,30)
root = np.zeros_like(kw)
from scipy.optimize import minimize
Gam =0.25
# gam = 0.2 gam
for j in range(np.shape(kw)[0]):
    a = A[4]
    kw_val = kw[j]
    print(Func(minF(a,kw_val),a,kw_val,Gam,sgam,mp),Func(maxF(a,kw_val),a,kw_val,Gam,sgam,mp))
    try:
        r=root_scalar(Func,args=(a,kw_val,Gam,sgam,mp),method='bisect',bracket=(minF(a,kw_val),maxF(a,kw_val)))
            # print(r.root)
    except:
        print(j)
                
        # bracket=[minF(a)-1/10**3,maxF(a)+1/10**3],
        # check[i,j] = func_B(kw_val,a,Gam,sgam,mp)
        # conv[i,j]= r.converged
    root[j]= r.root

def loss(p):
    res = 0
    for i in range(4):
        res += 1

def damp0(kw,a,Gam):
    return (2+np.sqrt(1-3*(2*Gam**2+a)*kw))/3
plt.figure()
plt.plot(kw,1-3*(2*Gam**2+a)*kw**2)
plt.scatter(kw,root)
plt.hlines(0,kw[0],kw[-1])
plt.show()
        # trash,damp[i,j,k], lamda[i,j,k]= lam1(r.root,a,kw_val,Gam,sgam,mp)
# Out:
# -0.14814814814814814 0.0
# -0.16018905877585932 -0.004865845224502063
# 1
# -0.1966451230971408 -0.019130048459860216
# 2
# -0.2584694543863936 -0.041839496431673506
# 3
# -0.34711846491435816 -0.0715377768692016
# 4
# -0.46441556175185406 -0.10640148270162486
# 5
# -0.6124329783593143 -0.14435838046851046
# 6
# -0.7934050238023145 -0.18317416110428253
# 7
# -1.0096700091757926 -0.2205105135140033
# 8
# -1.2636331044050955 -0.2539622677723252
# 9
# -1.557742970815033 -0.2810807625544389
# 10
# -1.8944770478153143 -0.29938855845063594
# 11
# -2.27633218953426 -0.30638880133259416
# 12
# -2.705818611385359 -0.2995712757868274
# 13
# -3.1854559050139626 -0.2764163901679808
# 14
# -3.717770365052088 -0.23439784984404
# 15
# -4.305293162162395 -0.17098448415234202
# 16
# -4.950559071878238 -0.0836415175595393
# 17
# -5.6561055750083815 0.03016853074314252
# -6.424472210765845 0.17298519996871775
# -7.258200104646489 0.34734961561304445
# -8.159831619039968 0.5558041400657796
# -9.131910091313683 0.800892110694325
# -10.176979635103583 1.0851576411346269
# -11.297584987869527 1.4111454688465486
# -12.496271392724752 1.7814008369433285
# -13.775584505944385 2.198469401700086
# -15.138070323917383 2.6648971595057755
# -16.586275124966647 3.1832303886833184
# -18.122745422644616 3.756015602785137

# %%
cm = 1/2.54  
width = 10*cm 
name_of_plot = "sign_of_ev2_fix1.pdf"
plt.rcParams["lines.markersize"]=0.7
plt.rcParams["axes.unicode_minus"]=True
plt.rcParams["font.size"]=10
plt.rcParams["text.usetex"]=True
plt.rcParams["font.serif"]="Computer Modern Serif"

nplots =2   
fig, ax = plt.subplots(1,nplots,figsize=(2*width,4.8/6.4*width),dpi=400)
images = []
# ax[n].scatter(A,root,color='0')
for n in range(nplots):



# axlimits have to be adapted
# ax[n].set_xlim(A[0],A[-1])
# ax[n].set_ylim(-2.5,3.5)

# legend has to be adapted
# plt.legend([r'$r_{\lambda_1}^{max}$',r'$\tilde{y}_{max}$',r'$r_{\lambda_1}^{min}$'],loc='center left',bbox_to_anchor=(0.01,0.38))
# plt.legend([r'$r$',r'$r$',r'$y_{max}$'],loc='center left',bbox_to_anchor=(0.2,0.5))

    major_xtick_step = 8
    minor_xtick_step = 1.5
    major_ytick_step = 8
    minor_ytick_step = 1.5
    STRIP_OF_ZEROS_X = True
    STRIP_OF_ZEROS_Y = True


    # def strip0(x,pos):
    #     if x<0: 
    #         return u'\u2212'+ str(x).rstrip(".0").lstrip("-")
    #     else:
    #         if str(x).rstrip(".0"):
    #             return str(x).rstrip(".0")
    #     return "0"
    im = ax[n].imshow(np.sign(lamda[:,:,n]),cmap='gray')
    im.set_extent((-0.5,39.5,29.5,-0.5))
    trash, xw, yw, trash= im.get_extent()
    numb_xticks = xw//major_xtick_step+1
    numb_yticks = yw//major_ytick_step+1
    def formatx0(x,pos):
        try:

            # print(x,pos)#,"{:.2f}".format(kw[int(x)]))
            
            index = int((pos-1)*kw.shape[0]//numb_xticks)
            # print(index)
            # print()
            return "{:.2f}".format(kw[index,0])
        except:
            return "{:.2f}".format(kw[-1,0])
    def formatx1(x,pos):
        try:

            # print(x,pos)#,"{:.2f}".format(kw[int(x)]))
            
            index = int((pos-1)*kw.shape[0]//numb_xticks)
            # print(index)
            # print()
            return "{:.1f}".format(kw[index,1])
        except:
            return "{:.1f}".format(kw[-1,1])
    def formaty(x,pos):
        try:
            index = int((pos-1)*len(A)//numb_yticks)
            return "{:.2f}".format(A[index])
        except:
            return "{:.2f}".format(A[-1])
    ax[n].yaxis.set_major_locator(ticker.MultipleLocator(major_ytick_step))
    ax[n].yaxis.set_minor_locator(ticker.MultipleLocator(minor_ytick_step))
    ax[n].xaxis.set_major_locator(ticker.MultipleLocator(major_xtick_step))
    ax[n].xaxis.set_minor_locator(ticker.MultipleLocator(minor_xtick_step))
    if STRIP_OF_ZEROS_X:
        if n==0:
            ax[n].xaxis.set_major_formatter(ticker.FuncFormatter(formatx0))
        else:
            ax[n].xaxis.set_major_formatter(ticker.FuncFormatter(formatx1))
    if STRIP_OF_ZEROS_Y:
        ax[n].yaxis.set_major_formatter(ticker.FuncFormatter(formaty))  
    ax[n].tick_params(axis='x',direction='in',which='both',bottom=True,top=True,labelbottom=True)
    ax[n].tick_params(axis='both',which='major',length=4.5)
    ax[n].tick_params(axis='y',direction='in',which='both',left=True,right=True,labelleft=True)
    ax[n].set_ylabel(r'$\Gamma A$',rotation=0)
    ax[n].set_xlabel(r'$$\frac{\kappa_np}{\omega}$$',rotation=0)
plt.subplots_adjust(wspace=0.26)

# ax.set_xticks(np.arange(len(kw)),kw)
# ax.set_yticks(np.arange(len(A)),A)
cbar = ax[1].figure.colorbar(im,ax=ax,ticks=ticker.MultipleLocator(1),label=r'sign$(p^2-4q)$',pad=0.02,shrink=0.743)
# ax.figure.set_size_inches(width,4.8/6.4*width)
# fig.set_size_inches(width,4.8/6.4*width)


# fig.tight_layout()
# plt.savefig('/home/christian/Documents/Bachelor/protocol/pictures/'+name_of_plot,bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 54, in formatx0(x, pos)
#      52     # print(index)
#      53     # print()
# ---> 54     return "{:.2f}".format(kw[index,0])
#      55 except:
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File /usr/lib/python3/dist-packages/matplotlib/backend_bases.py:2314, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2308     renderer = _get_renderer(
#    2309         self.figure,
#    2310         functools.partial(
#    2311             print_method, orientation=orientation)
#    2312     )
#    2313     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2314         self.figure.draw(renderer)
#    2316 if bbox_inches:
#    2317     if bbox_inches == "tight":
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3/dist-packages/matplotlib/figure.py:3082, in Figure.draw(self, renderer)
#    3079         # ValueError can occur when resizing a window.
#    3081 self.patch.draw(renderer)
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.suppressComposite)
#    3085 for sfig in self.subfigs:
#    3086     sfig.draw(renderer)
#
# File /usr/lib/python3/dist-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:3100, in _AxesBase.draw(self, renderer)
#    3097         a.draw(renderer)
#    3098     renderer.stop_rasterizing()
# -> 3100 mimage._draw_list_compositing_images(
#    3101     renderer, self, artists, self.figure.suppressComposite)
#    3103 renderer.close_group('axes')
#    3104 self.stale = False
#
# File /usr/lib/python3/dist-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1304, in Axis.draw(self, renderer, *args, **kwargs)
#    1301     return
#    1302 renderer.open_group(__name__, gid=self.get_gid())
# -> 1304 ticks_to_draw = self._update_ticks()
#    1305 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1307 for tick in ticks_to_draw:
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1191, in Axis._update_ticks(self)
#    1186 """
#    1187 Update ticks (position and labels) using the current data interval of
#    1188 the axes.  Return the list of ticks that will be drawn.
#    1189 """
#    1190 major_locs = self.get_majorticklocs()
# -> 1191 major_labels = self.major.formatter.format_ticks(major_locs)
#    1192 major_ticks = self.get_major_ticks(len(major_locs))
#    1193 self.major.formatter.set_locs(major_locs)
#
# File /usr/lib/python3/dist-packages/matplotlib/ticker.py:233, in Formatter.format_ticks(self, values)
#     231 """Return the tick labels for all the ticks at once."""
#     232 self.set_locs(values)
# --> 233 return [self(value, i) for i, value in enumerate(values)]
#
# File /usr/lib/python3/dist-packages/matplotlib/ticker.py:340, in FuncFormatter.__call__(self, x, pos)
#     334 def __call__(self, x, pos=None):
#     335     """
#     336     Return the value of the user defined function.
#     337
#     338     *x* and *pos* are passed through as-is.
#     339     """
# --> 340     return self.func(x, pos)
#
# Cell In[12], line 56, in formatx0(x, pos)
#      54     return "{:.2f}".format(kw[index,0])
#      55 except:
# ---> 56     return "{:.2f}".format(kw[-1,0])
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
from sympy.abc import gamma, G, kappa, omega, x, y, z, t
from sympy.matrices import Matrix
from sympy import lambdify
import numpy as np
m = Matrix([x,y,z])
glx = -(gamma+G)/2*m[0]+kappa*m[0]*m[2]/np.sqrt(2)
gly = -omega*m[2]/np.sqrt(2)-(gamma+G)/2*m[1]+kappa*m[1]*m[2]/np.sqrt(2)
glz = omega*m[1]/np.sqrt(2)-kappa*(m[0]**2+m[1]**2)/np.sqrt(2)+G/2-G*m[2]
gl = Matrix([glx,gly,glz])
jac_gl = gl.jacobian([x,y,z])
gl_np = lambdify([t,m,kappa,omega,gamma,G],gl)
jac_gl_np = lambdify([t,m,kappa,omega,gamma,G],jac_gl)
gl_np(0,[0,2,1],1,1/2,0.2,1), jac_gl_np(0,[0,2,1],1,1/2,0.2,1)
from scipy.integrate import solve_ivp
k = kappa_np(-A[6],1,0.2,1)
# arguments = [k,k/kw[6,1],0.2,1]
def m_z(x,y,G,kappa,omega):
    return 1/2-(kappa*(x**2+y**2)-omega*y)/G/np.sqrt(2)
# msol = [0,root[6,6]/kw[6,1],m_z(0,root[6,6]/kw[6,1],1,k,k/kw[6,1])]
# gl_np(0,msol,k,k/kw[6,1],0.2,1)
a=-0.05
kw=0.3
g = 0.2
G=1
k= kappa_np(a,G,g,1)
w= k/kw
arguments = [k,w,0.2,1]
# def Func(y,A,kw,Gam,sgam,mp):
# a = G*(G+g-k/np.sqrt(2))
# print(kappa_np(a,G,g,1))
def F(y,G,gamma,kappa,omega):
    return -omega*G/np.sqrt(2)/k**2-(G*(G+gamma-k/np.sqrt(2))/k**2+omega**2/kappa**2)*y-y**3+2*omega/kappa*y**2
r = root_scalar(Func,args=(a,k/w,G,g,1),method='brentq',bracket=(-200,0))
print(r)
msol2= np.array([0,r.root*w/k,m_z(0,r.root*w/k,G,k,w)])+6*np.array([0.5,-1,0.5])
gl_np(0,msol2,k,w,g,G)
traj = solve_ivp(gl_np,(0,100),msol2,'LSODA',jac=jac_gl_np,args=arguments)
plt.figure()
plt.plot(traj.t,traj.y[0])
plt.plot(traj.t,traj.y[1])
plt.plot(traj.t,traj.y[2])
plt.legend(['x','y','z'])
plt.show()
plt.figure()
plt.plot(traj.y[1],traj.y[2])
# Out:
#       converged: True
#            flag: converged
#  function_calls: 8
#      iterations: 7
#            root: -0.030517133091117938
